# %%
#assigning values to a variable
a= 10
b= 'edureka'
c= 10.5

print (a)
print (b)
print (c)

# %%
#data_types_numeric
a= 20
print (a)

c=2.35
print (c)

d= float(a)
print(d)

e = int(c)
print (e)

#Boolean
number = [1, 2, 3, 4, 5]
boolean = 3 in number
print(boolean)

# %%
#data_types_lists
#define a list
task = ['brush', 'bath', 'office', 'drink']
print(task)

#update a list
task[1]='dryclean'
print(task)

#print the length of a list
print(len(task))

#print an element of the list
print(task[2])

#print a part of the list
print(task [0:3])

#concatenation of list
list1= ['physics', 'python', 'hadoop']
print(task+list1)

#print list mutiple times
print(task*2)

# %%
#data_types_tuples
task2 = ('brush', 'bath', 'office', 'drink')
print(task2)

#upate a tuple
#task2[1]='dryclean'
#print(task2) # can not be updates like lists

#print the length of a tuple
print(len(task2))

#print an element of the tuple
w= task2[2]
print(w)

#print a part of the tuple
print(task2[0:3])

#concatenation of tuple
task3 = ('physics', 'math','linguistics')
print(task2+task3)

#print tuple mutiple times
print(task2*3)

# %%
#data_types_string
a= 'welcome to edureka'
print (a)
print (len(a))

#locate a character in a string
print (a.index('l'))

#count the number of times the character is repaeted in the string
print (a.count('e'))

#print a part of the string
print (a[0:3])

#recerse a string
print (a[::-1])

#convert the letter in the string to uppercase
print (a.upper())

#convert the letter in the string to lowercase
print (a.lower())

#concatenation of strings
print (a+'python')

#print a string mutiple time
print (a*3)

# %%
#data_types_sets
#define a set
l = ['s', 's', 'p']
g = set (l)
print (g)

# %%
#data_types_dictionary

a = {'name':'Neel', 'age':'56'}
print (a['name'])
print (a['age'])

# %%
#operations_arthematic_operator

#addition 
a = 10
b = 20
c = a+b
print (c)

#subtraction
d= a-b
print (d)

#multiplication
f= a*b
print(f)
 
#division
s = a/b
print(s)

#modulus
x= b%a
print(x)

#exponent
z= a**b
print(z)

# %%
#operation_comparision_operator
#equal value oftwo operands
a = 10
b = 10
if (a==b):
    print('a and b are same')
    

#if the value of two operands is not same
    
c = 20
d = 10
if (c!=d):
    print ('c and d are not same')

#if the left operand is greater than right

q = 33
w = 30
if (q>w):
    print ('q is greater')

#if the right operand is greater than left
    
x = 20
y = 25
if (x<y):
    print ('y is greater')

#if the left operand is greater than or equal to right

p = 20
z = 20
if (p >=z):
     print ('p is greater or equal to z')

#if the right operand is greater than or equal to left
j = 20
i = 30
if(j<=i):
    print ('i is greater than or equal to j')

# %%
#operation_assignment_operator
a = 21
b = 10
c = 0

c = a+b
print (c)

c += a
print (c)

c -= a
print (c)

c *= a
print (c)

c /= a
print (c)

c %=a
print (c)

c **=a
print (c)

# %%
#operation_identity_operator

a = 10
b =10
if (a is b):
    print ('a is present in b')
    
p =10
q = 12

if (p is not q):
    print ('p is present in q')

# %%
#operation_membership_operator

a = 10
list1 = [10,20,30,40]
if (a in list1):
    print ('a is present in list')
    
b = 22
type1= [20, 30, 40, 50]
if (b not in type1):
    print ('b is present in type1')

# %%
#Conditional_statements
a = 20
b = 25
if (a>b):
    print ('a is greater')
elif (a<b):
    print ('a is smaller')
else:
    print ('a is equal to be')

# %%
#loop
#while loop

count = 0
while (count <9):
    print ('the count:',count)
    count = count +1
print ('good bye')

#for loop
for  x in range (5):
    print (x)
    
for x in range (3,6):
    print (x)
    
examplelist = [1, 5, 6, 1, 6, 7, 8, 9, 345, 53, 5]
for eachNumber in examplelist:
    print (eachNumber)
    print ('continue program')
    
# nested loop

# %%
#functions in python are of two types: predefined and user defined
def example():
    print ('baic function')
    z = 3+8
    print (z)
    
example ()
# Out:
# baic function
# 11
